# %%
from pathlib import Path
import json
import re
import shutil
import pandas as pd
import cv2

# %%
prolific_dir = Path("./annotations/Prolific/labels")
crowdworks_dir = Path("./annotations/CrowdWorks/labels")
prolific_gen = prolific_dir.glob("*.json")
crowdworks_gen = crowdworks_dir.glob("*.json")

prolific_annotations = []
for file in prolific_gen:
    with open(file) as f:
        cur_ann = json.load(f)
        cur_ann["file"] = f"{file.stem.split("_")[0]}.jpg" 
        prolific_annotations.append(cur_ann)

crowdworks_annotations = []
for file in crowdworks_gen:
    with open(file) as f:
        cur_ann = json.load(f)
        cur_ann["file"] = f"{file.stem.split("_")[0]}.jpg" 
        crowdworks_annotations.append(cur_ann)

# %%
prolific_street_count = 0
for ann in prolific_annotations:
    for values in ann["manualAnnotation"].values():
        if "street" in values["category"].lower() and "sign" in values["category"].lower():
            prolific_street_count += 1
            continue
    for key in ann["defaultAnnotation"].keys():
        if "street" in key.lower() and "sign" in key.lower():
            prolific_street_count+=1

crowdworks_street_count = 0
for ann in crowdworks_annotations:
    for values in ann["manualAnnotation"].values():
        if "street" in values["category"].lower() and "sign" in values["category"].lower():
            crowdworks_street_count += 1
            continue
    for key in ann["defaultAnnotation"].keys():
        if "street" in key.lower() and "sign" in key.lower():
            crowdworks_street_count+=1

print(
    f"""
    prolific has {prolific_street_count} annotations with street signs.
    crowdworks has {crowdworks_street_count} annotations with street signs. 
    The total is {crowdworks_street_count + prolific_street_count}.
    """
    )
# Out:
#     prolific has 23 annotations with street signs.
#     crowdworks has 19 annotations with street signs.
#     The total is 42.

# %%
def is_class(category: str, description: str) -> bool:
    is_present = []
    for word in re.split(" |_", category):
        if word.lower() in description.lower():
            is_present.append(True)
        else:
            is_present.append(False)
    if all(is_present):
        return True
    return False

def sort_annotations(categories: list, annotations: list) -> dict:
    bins = {}
    for category in categories:
        bins[category] = []
    for ann in annotations:
        for category in categories:
            for key in ann["defaultAnnotation"]:
                if is_class(category, key):
                    bins[category].append(ann)
                    break
            for value in list(ann["manualAnnotation"].values()):
                description = value["category"]
                if is_class(category, description):
                    bins[category].append(ann)
                    break

    return bins

def get_manual(annotations: dict, categories=None) -> dict:
    if categories is None:
        categories = list(annotations.keys())
    if isinstance(categories, str):
        categories = [categories]
    bins = {}
    for category in categories:
        bins[category] = []
        for ann in annotations[category]:
            for value in list(ann["manualAnnotation"].values()):
                description = value["category"]
                if is_class(category, description):
                    bins[category].append(ann)
                    break
    for class_name in bins.keys():
        print(f"There are {len(bins[class_name])} manual annotations for class {class_name}")
    return bins          

def normalize_bbox(bbox: list, width, height) -> list:
    """
    Normalize by dividing x_center and width by image width, and y_center and height by image height.
    """
    bbox[0] /= width
    bbox[2] /= width
    bbox[1] /= height
    bbox[3] /= height

    return bbox

def ann_to_string(annotation: dict, class_name: str, class_map: dict, bbox_width, bbox_height) -> str:
    man_ann = annotation["manualAnnotation"]
    class_number = class_map[class_name]
    bbox = None
    for key in man_ann:
        description = man_ann[key]["category"]
        if is_class(class_name, description):
            bbox = man_ann[key]["bbox"]
            break
    if bbox is None:
        return

    # normalize bbox values for YOLO
    # note that bbox is annotations is given in format [x_centre, y_centre, width, height], which is also YOLO format
    bbox = normalize_bbox(bbox, bbox_width, bbox_height) 
    bbox = [str(el) for el in bbox]
    
    return f"{class_number} {' '.join(bbox)} \n"

def get_image_dimensions(filename, image_dir = Path("./images")) -> tuple:
    if isinstance(image_dir, str):
        image_dir = Path(image_dir)
    if not isinstance(filename, str):
            filename = str(filename)

    image = cv2.imread(image_dir / filename)
    height, width, _ = image.shape

    return (height, width)

# directory structure: 
# ../images/image_pool/object_class/image.image,
# ../images/image_pool/object_class/unbounded/image.image,
# ../labels/image_pool/object_class/text.txt, 
# ../labels/image_pool/object_class/unbounded/text.txt.

def save_image_and_txt(annotations: dict, class_map: dict, image_dir=None, dest_dir=None):
    """
    Function to create/fill a directory with images and txt files suitable for use with YOLO. 
    Expects a dict where each key is a class of objects and each value is a list of annotations. 
    Can be passed a source directory for images and destination directory, otherwise defaults are
    ./images and ../training.
    """
    if image_dir is None:
        image_dir = Path("./images")
    elif isinstance(image_dir, str):
        image_dir = Path(image_dir)
    assert image_dir.exists(), "Image directory not found"
    
    if dest_dir is None:
        dest_dir = Path("..")
    elif isinstance(dest_dir, str):
        dest_dir = Path(dest_dir)
        
    image_dir_new = dest_dir / "images/image_pool"
    image_info_dir = dest_dir / "labels/image_pool"
    
    # create subdirectories for objects classes
    for key in annotations:
        class_image_dir = image_dir_new / key
        class_image_info_dir = image_info_dir / key
    # since only bounded images are useful, they go in the main directory, unbounded images go in subdirectory
        class_image_dir_unbounded = class_image_dir / "unbounded"
        class_image_info_dir_unbounded = class_image_info_dir / "unbounded"
        if not class_image_dir_unbounded.exists():
            class_image_dir_unbounded.mkdir(parents=True)
        if not class_image_info_dir_unbounded.exists():
            class_image_info_dir_unbounded.mkdir(parents=True)
    
    # loop through object categories to add images and labels
    for key in annotations:
        cur_image_dir = image_dir_new / key
        cur_info_dir = image_info_dir / key
        cur_manual = get_manual(annotations, key)

        # first we put in place images that do have manual annotations for the class in question, and therefore
        # bounding boxes (which we use to make the labels)
        for ann in cur_manual[key]:
            filename = ann["file"]
            label_filename = filename.split(".")[0] + ".txt"
            height, width = get_image_dimensions(filename)
            label_contents = ann_to_string(ann, key, class_map, width, height)
            cur_image_path = cur_image_dir / filename
            cur_label_path = cur_info_dir / label_filename
            if not cur_image_path.exists():
                shutil.copy(image_dir / filename, cur_image_dir)
            if cur_label_path.exists():
                with cur_label_path.open("a") as f:
                    f.write(label_contents)
            else:
                cur_label_path.write_text(label_contents)

        # now we look through all the annotations by class, skipping any cases where we already have processed the annotation+class
        # for its manual annotation. 
        for ann in annotations[key]:
            filename = ann["file"]
            if (cur_image_dir / filename).exists():
                continue
            unbounded_image_path = cur_image_dir / "unbounded"
            shutil.copy(image_dir / filename, unbounded_image_path)

# %%
class_map = {"face": 0, "license plate": 1, "picture": 2, "street sign": 3}
categories = list(class_map.keys())
sorted_annotations = sort_annotations(categories, prolific_annotations+crowdworks_annotations)
save_image_and_txt(sorted_annotations, class_map)
# Out:
# There are 50 manual annotations for class face
# There are 2 manual annotations for class license plate
# There are 1 manual annotations for class picture
# There are 4 manual annotations for class street sign

# %%
sorted_annotations["face"]
# Out:
# [{'source': 'OpenImages',
#   'workerId': '5bfb0ed98422770001d9873f',
#   'defaultAnnotation': {'Human face': {'category': 'Human face',
#     'informationType': '1',
#     'informationTypeInput': '',
#     'sharing': '2',
#     'sharingInput': '',
#     'ifNoPrivacy': False,
#     'informativeness': 6},
#    'Dress': {'category': 'Dress',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'Suit': {'category': 'Suit',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'Human hair': {'category': 'Human hair',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'Glasses': {'category': 'Glasses',
#     'informationType': '1',
#     'informationTypeInput': '',
#     'sharing': '2',
#     'sharingInput': '',
#     'ifNoPrivacy': False,
#     'informativeness': 5},
#    'Fashion accessory': {'category': 'Fashion accessory',
#     'informationType': '1',
#     'informationTypeInput': '',
#     'sharing': '2',
#     'sharingInput': '',
#     'ifNoPrivacy': False,
#     'informativeness': 5},
#    'Girl': {'category': 'Girl',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'Human nose': {'category': 'Human nose',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'Human body': {'category': 'Human body',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'Rose': {'category': 'Rose',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'Human head': {'category': 'Human head',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'Human eye': {'category': 'Human eye',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'Human hand': {'category': 'Human hand',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'Mammal': {'category': 'Mammal',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'Human mouth': {'category': 'Human mouth',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'Boy': {'category': 'Boy',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'Human arm': {'category': 'Human arm',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'Woman': {'category': 'Woman',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'Man': {'category': 'Man',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4}},
#   'manualAnnotation': {},
#   'file': '0319faa662ff5d06.jpg'},
#  {'source': 'LVIS',
#   'workerId': '5cb260595730d8001a5ea7ac',
#   'defaultAnnotation': {'earphone': {'category': 'earphone',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'manhole': {'category': 'manhole',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'camera': {'category': 'camera',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'fireplug': {'category': 'fireplug',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'coat': {'category': 'coat',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'jacket': {'category': 'jacket',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4}},
#   'manualAnnotation': {'0': {'category': 'Individuals face',
#     'bbox': [56, 80, 53, 59],
#     'informationType': '1',
#     'informationTypeInput': '',
#     'sharing': '1',
#     'sharingInput': '',
#     'informativeness': 4}},
#   'file': '150265.jpg'},
#  {'source': 'OpenImages',
#   'workerId': '6090f952525df6a9a07b6921',
#   'defaultAnnotation': {'Human face': {'category': 'Human face',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'Human hair': {'category': 'Human hair',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'Human nose': {'category': 'Human nose',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'Human body': {'category': 'Human body',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'Human head': {'category': 'Human head',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'Human eye': {'category': 'Human eye',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'Mammal': {'category': 'Mammal',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'Human mouth': {'category': 'Human mouth',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'Boy': {'category': 'Boy',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'Helmet': {'category': 'Helmet',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'Football helmet': {'category': 'Football helmet',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4}},
#   'manualAnnotation': {},
#   'file': '020c7b8e6d605069.jpg'},
#  {'source': 'OpenImages',
#   'workerId': '60e59a8dac13439f62987223',
#   'defaultAnnotation': {'Human face': {'category': 'Human face',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'Chair': {'category': 'Chair',
#     'informationType': '2',
#     'informationTypeInput': '',
#     'sharing': '3',
#     'sharingInput': '',
#     'ifNoPrivacy': False,
#     'informativeness': 4},
#    'Human hair': {'category': 'Human hair',
#     'informationType': '3',
#     'informationTypeInput': '',
#     'sharing': '3',
#     'sharingInput': '',
#     'ifNoPrivacy': False,
#     'informativeness': 5},
#    'Furniture': {'category': 'Furniture',
#     'informationType': '1',
#     'informationTypeInput': '',
#     'sharing': '3',
#     'sharingInput': '',
#     'ifNoPrivacy': False,
#     'informativeness': 5},
#    'Clothing': {'category': 'Clothing',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'Human body': {'category': 'Human body',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'Human head': {'category': 'Human head',
#     'informationType': '3',
#     'informationTypeInput': '',
#     'sharing': '2',
#     'sharingInput': '',
#     'ifNoPrivacy': False,
#     'informativeness': 4},
#    'Mammal': {'category': 'Mammal',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'Human ear': {'category': 'Human ear',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'Woman': {'category': 'Woman',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4}},
#   'manualAnnotation': {},
#   'file': '2a3513ff487baa5e.jpg'},
#  {'source': 'OpenImages',
#   'workerId': '63222311994c6e4c35bb2a55',
#   'defaultAnnotation': {'Human face': {'category': 'Human face',
#     'informationType': '1',
#     'informationTypeInput': '',
#     'sharing': '2',
#     'sharingInput': '',
#     'ifNoPrivacy': False,
#     'informativeness': 5},
#    'Human hair': {'category': 'Human hair',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'Computer monitor': {'category': 'Computer monitor',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'Television': {'category': 'Television',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'Person': {'category': 'Person',
#     'informationType': '1',
#     'informationTypeInput': '',
#     'sharing': '2',
#     'sharingInput': '',
#     'ifNoPrivacy': False,
#     'informativeness': 5},
#    'Human nose': {'category': 'Human nose',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'Clothing': {'category': 'Clothing',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'Human body': {'category': 'Human body',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'Human head': {'category': 'Human head',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'Human eye': {'category': 'Human eye',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'Mammal': {'category': 'Mammal',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'Human ear': {'category': 'Human ear',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'Human mouth': {'category': 'Human mouth',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'Human arm': {'category': 'Human arm',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'Man': {'category': 'Man',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4}},
#   'manualAnnotation': {},
#   'file': '45a98c6eb828a0c9.jpg'},
#  {'source': 'OpenImages',
#   'workerId': '5ef4e343d0a7dd102a3c50b8',
#   'defaultAnnotation': {'Human face': {'category': 'Human face',
#     'informationType': '1',
#     'informationTypeInput': '',
#     'sharing': '2',
#     'sharingInput': '',
#     'ifNoPrivacy': False,
#     'informativeness': 6},
#    'Human hair': {'category': 'Human hair',
#     'informationType': '1',
#     'informationTypeInput': '',
#     'sharing': '2',
#     'sharingInput': '',
#     'ifNoPrivacy': False,
#     'informativeness': 5},
#    'Human leg': {'category': 'Human leg',
#     'informationType': '1',
#     'informationTypeInput': '',
#     'sharing': '2',
#     'sharingInput': '',
#     'ifNoPrivacy': False,
#     'informativeness': 5},
#    'Car': {'category': 'Car',
#     'informationType': '3',
#     'informationTypeInput': '',
#     'sharing': '2',
#     'sharingInput': '',
#     'ifNoPrivacy': False,
#     'informativeness': 1},
#    'Person': {'category': 'Person',
#     'informationType': '1',
#     'informationTypeInput': '',
#     'sharing': '2',
#     'sharingInput': '',
#     'ifNoPrivacy': False,
#     'informativeness': 5},
#    'Human nose': {'category': 'Human nose',
#     'informationType': '1',
#     'informationTypeInput': '',
#     'sharing': '2',
#     'sharingInput': '',
#     'ifNoPrivacy': False,
#     'informativeness': 6},
#    'Clothing': {'category': 'Clothing',
#     'informationType': '1',
#     'informationTypeInput': '',
#     'sharing': '2',
#     'sharingInput': '',
#     'ifNoPrivacy': False,
#     'informativeness': 3},
#    'Human body': {'category': 'Human body',
#     'informationType': '1',
#     'informationTypeInput': '',
#     'sharing': '2',
#     'sharingInput': '',
#     'ifNoPrivacy': False,
#     'informativeness': 6},
#    'Human head': {'category': 'Human head',
#     'informationType': '1',
#     'informationTypeInput': '',
#     'sharing': '2',
#     'sharingInput': '',
#     'ifNoPrivacy': False,
#     'informativeness': 6},
#    'Human eye': {'category': 'Human eye',
#     'informationType': '1',
#     'informationTypeInput': '',
#     'sharing': '2',
#     'sharingInput': '',
#     'ifNoPrivacy': False,
#     'informativeness': 5},
#    'Human hand': {'category': 'Human hand',
#     'informationType': '1',
#     'informationTypeInput': '',
#     'sharing': '2',
#     'sharingInput': '',
#     'ifNoPrivacy': False,
#     'informativeness': 5},
#    'Footwear': {'category': 'Footwear',
#     'informationType': '1',
#     'informationTypeInput': '',
#     'sharing': '2',
#     'sharingInput': '',
#     'ifNoPrivacy': False,
#     'informativeness': 2},
#    'Wheel': {'category': 'Wheel',
#     'informationType': '3',
#     'informationTypeInput': '',
#     'sharing': '2',
#     'sharingInput': '',
#     'ifNoPrivacy': False,
#     'informativeness': 1},
#    'Boy': {'category': 'Boy',
#     'informationType': '1',
#     'informationTypeInput': '',
#     'sharing': '2',
#     'sharingInput': '',
#     'ifNoPrivacy': False,
#     'informativeness': 6},
#    'Toy': {'category': 'Toy',
#     'informationType': '3',
#     'informationTypeInput': '',
#     'sharing': '2',
#     'sharingInput': '',
#     'ifNoPrivacy': False,
#     'informativeness': 2},
#    'Human arm': {'category': 'Human arm',
#     'informationType': '1',
#     'informationTypeInput': '',
#     'sharing': '2',
#     'sharingInput': '',
#     'ifNoPrivacy': False,
#     'informativeness': 5}},
#   'manualAnnotation': {},
#   'file': '1ffc718338acc984.jpg'},
#  {'source': 'OpenImages',
#   'workerId': '58f3d7699fbdde00011e99f7',
#   'defaultAnnotation': {'Human face': {'category': 'Human face',
#     'informationType': '1',
#     'informationTypeInput': '',
#     'sharing': '2',
#     'sharingInput': '',
#     'ifNoPrivacy': False,
#     'informativeness': 5},
#    'Human hair': {'category': 'Human hair',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'Human nose': {'category': 'Human nose',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'Clothing': {'category': 'Clothing',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'Human body': {'category': 'Human body',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'Human head': {'category': 'Human head',
#     'informationType': '1',
#     'informationTypeInput': '',
#     'sharing': '2',
#     'sharingInput': '',
#     'ifNoPrivacy': False,
#     'informativeness': 5},
#    'Human hand': {'category': 'Human hand',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'Human arm': {'category': 'Human arm',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'Woman': {'category': 'Woman',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'Man': {'category': 'Man',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4}},
#   'manualAnnotation': {},
#   'file': '01c9c7321fe8e116.jpg'},
#  {'source': 'OpenImages',
#   'workerId': '5b79e92cdb11320001c3d5da',
#   'defaultAnnotation': {'Human face': {'category': 'Human face',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'Human hair': {'category': 'Human hair',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'Glasses': {'category': 'Glasses',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'Fashion accessory': {'category': 'Fashion accessory',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'Girl': {'category': 'Girl',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'Sun hat': {'category': 'Sun hat',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'Human nose': {'category': 'Human nose',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'Human body': {'category': 'Human body',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'Human head': {'category': 'Human head',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'Human eye': {'category': 'Human eye',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'Mammal': {'category': 'Mammal',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'Cowboy hat': {'category': 'Cowboy hat',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'Human mouth': {'category': 'Human mouth',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'Fedora': {'category': 'Fedora',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'Woman': {'category': 'Woman',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4}},
#   'manualAnnotation': {},
#   'file': '081b5acdf94c392a.jpg'},
#  {'source': 'OpenImages',
#   'workerId': '5f4eb1a2c296ed0e5a786977',
#   'defaultAnnotation': {'Hat': {'category': 'Hat',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'Human face': {'category': 'Human face',
#     'informationType': '4',
#     'informationTypeInput': '',
#     'sharing': '2',
#     'sharingInput': '',
#     'ifNoPrivacy': False,
#     'informativeness': 5},
#    'Human hair': {'category': 'Human hair',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'Glasses': {'category': 'Glasses',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'Fashion accessory': {'category': 'Fashion accessory',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'Girl': {'category': 'Girl',
#     'informationType': '4',
#     'informationTypeInput': '',
#     'sharing': '2',
#     'sharingInput': '',
#     'ifNoPrivacy': False,
#     'informativeness': 3},
#    'Sunglasses': {'category': 'Sunglasses',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'Human nose': {'category': 'Human nose',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'Clothing': {'category': 'Clothing',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'Human body': {'category': 'Human body',
#     'informationType': '1',
#     'informationTypeInput': '',
#     'sharing': '2',
#     'sharingInput': '',
#     'ifNoPrivacy': False,
#     'informativeness': 5},
#    'Human head': {'category': 'Human head',
#     'informationType': '1',
#     'informationTypeInput': '',
#     'sharing': '2',
#     'sharingInput': '',
#     'ifNoPrivacy': False,
#     'informativeness': 5},
#    'Human eye': {'category': 'Human eye',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'Human mouth': {'category': 'Human mouth',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'Goggles': {'category': 'Goggles',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'Woman': {'category': 'Woman',
#     'informationType': '1',
#     'informationTypeInput': '',
#     'sharing': '2',
#     'sharingInput': '',
#     'ifNoPrivacy': False,
#     'informativeness': 5}},
#   'manualAnnotation': {},
#   'file': '337c8bda1d64f472.jpg'},
#  {'source': 'OpenImages',
#   'workerId': '5da760eae8174b001640d369',
#   'defaultAnnotation': {'Human face': {'category': 'Human face',
#     'informationType': '1',
#     'informationTypeInput': '',
#     'sharing': '2',
#     'sharingInput': '',
#     'ifNoPrivacy': False,
#     'informativeness': 6},
#    'Human hair': {'category': 'Human hair',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'Car': {'category': 'Car',
#     'informationType': '5',
#     'informationTypeInput': 'REGISTRATION',
#     'sharing': '2',
#     'sharingInput': '',
#     'ifNoPrivacy': False,
#     'informativeness': 5},
#    'Human head': {'category': 'Human head',
#     'informationType': '1',
#     'informationTypeInput': '',
#     'sharing': '2',
#     'sharingInput': '',
#     'ifNoPrivacy': False,
#     'informativeness': 6},
#    'Vehicle': {'category': 'Vehicle',
#     'informationType': '5',
#     'informationTypeInput': 'REGISTRATION',
#     'sharing': '2',
#     'sharingInput': '',
#     'ifNoPrivacy': False,
#     'informativeness': 5},
#    'Wheel': {'category': 'Wheel',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4}},
#   'manualAnnotation': {},
#   'file': '04833bdaa8c68594.jpg'},
#  {'source': 'LVIS',
#   'workerId': '60142f86044b153d7de0423e',
#   'defaultAnnotation': {'earphone': {'category': 'earphone',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'swimsuit': {'category': 'swimsuit',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'surfboard': {'category': 'surfboard',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'sunglasses': {'category': 'sunglasses',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'short_pants': {'category': 'short_pants',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'life_jacket': {'category': 'life_jacket',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4}},
#   'manualAnnotation': {'0': {'category': 'Face',
#     'bbox': [144, 150, 41, 34],
#     'informationType': '1',
#     'informationTypeInput': '',
#     'sharing': '1',
#     'sharingInput': '',
#     'informativeness': 5}},
#   'file': '123944.jpg'},
#  {'source': 'OpenImages',
#   'workerId': '5c4f5967aac8be0001716a65',
#   'defaultAnnotation': {'Human face': {'category': 'Human face',
#     'informationType': '1',
#     'informationTypeInput': '',
#     'sharing': '2',
#     'sharingInput': '',
#     'ifNoPrivacy': False,
#     'informativeness': 7},
#    'Human hair': {'category': 'Human hair',
#     'informationType': '1',
#     'informationTypeInput': '',
#     'sharing': '2',
#     'sharingInput': '',
#     'ifNoPrivacy': False,
#     'informativeness': 6},
#    'Girl': {'category': 'Girl',
#     'informationType': '1',
#     'informationTypeInput': '',
#     'sharing': '2',
#     'sharingInput': '',
#     'ifNoPrivacy': False,
#     'informativeness': 7},
#    'Human nose': {'category': 'Human nose',
#     'informationType': '1',
#     'informationTypeInput': '',
#     'sharing': '2',
#     'sharingInput': '',
#     'ifNoPrivacy': False,
#     'informativeness': 6},
#    'Clothing': {'category': 'Clothing',
#     'informationType': '3',
#     'informationTypeInput': '',
#     'sharing': '3',
#     'sharingInput': '',
#     'ifNoPrivacy': False,
#     'informativeness': 5},
#    'Human body': {'category': 'Human body',
#     'informationType': '1',
#     'informationTypeInput': '',
#     'sharing': '2',
#     'sharingInput': '',
#     'ifNoPrivacy': False,
#     'informativeness': 5},
#    'Human head': {'category': 'Human head',
#     'informationType': '1',
#     'informationTypeInput': '',
#     'sharing': '2',
#     'sharingInput': '',
#     'ifNoPrivacy': False,
#     'informativeness': 7},
#    'Human eye': {'category': 'Human eye',
#     'informationType': '1',
#     'informationTypeInput': '',
#     'sharing': '2',
#     'sharingInput': '',
#     'ifNoPrivacy': False,
#     'informativeness': 6},
#    'Human hand': {'category': 'Human hand',
#     'informationType': '1',
#     'informationTypeInput': '',
#     'sharing': '2',
#     'sharingInput': '',
#     'ifNoPrivacy': False,
#     'informativeness': 2},
#    'Mammal': {'category': 'Mammal',
#     'informationType': '1',
#     'informationTypeInput': '',
#     'sharing': '2',
#     'sharingInput': '',
#     'ifNoPrivacy': False,
#     'informativeness': 7},
#    'Human mouth': {'category': 'Human mouth',
#     'informationType': '1',
#     'informationTypeInput': '',
#     'sharing': '2',
#     'sharingInput': '',
#     'ifNoPrivacy': False,
#     'informativeness': 6},
#    'Laptop': {'category': 'Laptop',
#     'informationType': '3',
#     'informationTypeInput': '',
#     'sharing': '2',
#     'sharingInput': '',
#     'ifNoPrivacy': False,
#     'informativeness': 5},
#    'Human arm': {'category': 'Human arm',
#     'informationType': '1',
#     'informationTypeInput': '',
#     'sharing': '2',
#     'sharingInput': '',
#     'ifNoPrivacy': False,
#     'informativeness': 3},
#    'Woman': {'category': 'Woman',
#     'informationType': '1',
#     'informationTypeInput': '',
#     'sharing': '2',
#     'sharingInput': '',
#     'ifNoPrivacy': False,
#     'informativeness': 7}},
#   'manualAnnotation': {},
#   'file': '5bcc87c13b42e844.jpg'},
#  {'source': 'OpenImages',
#   'workerId': '5a4937631950a80001e7d0e4',
#   'defaultAnnotation': {'Human face': {'category': 'Human face',
#     'informationType': '1',
#     'informationTypeInput': '',
#     'sharing': '2',
#     'sharingInput': '',
#     'ifNoPrivacy': False,
#     'informativeness': 6},
#    'Human hair': {'category': 'Human hair',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'Shirt': {'category': 'Shirt',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'Human nose': {'category': 'Human nose',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'Human body': {'category': 'Human body',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'Human head': {'category': 'Human head',
#     'informationType': '1',
#     'informationTypeInput': '',
#     'sharing': '2',
#     'sharingInput': '',
#     'ifNoPrivacy': False,
#     'informativeness': 6},
#    'Human eye': {'category': 'Human eye',
#     'informationType': '1',
#     'informationTypeInput': '',
#     'sharing': '2',
#     'sharingInput': '',
#     'ifNoPrivacy': False,
#     'informativeness': 4},
#    'Human beard': {'category': 'Human beard',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'Man': {'category': 'Man',
#     'informationType': '1',
#     'informationTypeInput': '',
#     'sharing': '2',
#     'sharingInput': '',
#     'ifNoPrivacy': False,
#     'informativeness': 5}},
#   'manualAnnotation': {},
#   'file': '02879d3014b69b1f.jpg'},
#  {'source': 'OpenImages',
#   'workerId': '5d70443e6f0a380017545335',
#   'defaultAnnotation': {'Human face': {'category': 'Human face',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'Human hair': {'category': 'Human hair',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'Human leg': {'category': 'Human leg',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'Girl': {'category': 'Girl',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'Human nose': {'category': 'Human nose',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'Clothing': {'category': 'Clothing',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'Human body': {'category': 'Human body',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'Human head': {'category': 'Human head',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'Human eye': {'category': 'Human eye',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'Human hand': {'category': 'Human hand',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'Human mouth': {'category': 'Human mouth',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'Boy': {'category': 'Boy',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'Bed': {'category': 'Bed',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'Human arm': {'category': 'Human arm',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4}},
#   'manualAnnotation': {},
#   'file': '2110e5d8ca7e5a99.jpg'},
#  {'source': 'OpenImages',
#   'workerId': '5bfb0ed98422770001d9873f',
#   'defaultAnnotation': {'Human face': {'category': 'Human face',
#     'informationType': '1',
#     'informationTypeInput': '',
#     'sharing': '2',
#     'sharingInput': '',
#     'ifNoPrivacy': False,
#     'informativeness': 7},
#    'Human hair': {'category': 'Human hair',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'Bookcase': {'category': 'Bookcase',
#     'informationType': '3',
#     'informationTypeInput': '',
#     'sharing': '2',
#     'sharingInput': '',
#     'ifNoPrivacy': False,
#     'informativeness': 4},
#    'Girl': {'category': 'Girl',
#     'informationType': '1',
#     'informationTypeInput': '',
#     'sharing': '2',
#     'sharingInput': '',
#     'ifNoPrivacy': False,
#     'informativeness': 4},
#    'Human nose': {'category': 'Human nose',
#     'informationType': '1',
#     'informationTypeInput': '',
#     'sharing': '1',
#     'sharingInput': '',
#     'ifNoPrivacy': False,
#     'informativeness': 4},
#    'Clothing': {'category': 'Clothing',
#     'informationType': '3',
#     'informationTypeInput': '',
#     'sharing': '2',
#     'sharingInput': '',
#     'ifNoPrivacy': False,
#     'informativeness': 4},
#    'Human head': {'category': 'Human head',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'House': {'category': 'House',
#     'informationType': '2',
#     'informationTypeInput': '',
#     'sharing': '2',
#     'sharingInput': '',
#     'ifNoPrivacy': False,
#     'informativeness': 6},
#    'Cabinetry': {'category': 'Cabinetry',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'Shelf': {'category': 'Shelf',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'Book': {'category': 'Book',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'Woman': {'category': 'Woman',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4}},
#   'manualAnnotation': {},
#   'file': '831ef1ed000ea182.jpg'},
#  {'source': 'OpenImages',
#   'workerId': '63223fa63b1c653f68731138',
#   'defaultAnnotation': {'Human face': {'category': 'Human face',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'Human hair': {'category': 'Human hair',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'Glasses': {'category': 'Glasses',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'Girl': {'category': 'Girl',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'Human nose': {'category': 'Human nose',
#     'informationType': '2',
#     'informationTypeInput': '',
#     'sharing': '1',
#     'sharingInput': '',
#     'ifNoPrivacy': False,
#     'informativeness': 5},
#    'Clothing': {'category': 'Clothing',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'Human body': {'category': 'Human body',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'Human head': {'category': 'Human head',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'Human hand': {'category': 'Human hand',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'Mammal': {'category': 'Mammal',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'Human mouth': {'category': 'Human mouth',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'Microphone': {'category': 'Microphone',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'Human arm': {'category': 'Human arm',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'Woman': {'category': 'Woman',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'Man': {'category': 'Man',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4}},
#   'manualAnnotation': {},
#   'file': '21269201fec8c14b.jpg'},
#  {'source': 'OpenImages',
#   'workerId': '5ba8438e168e5e0001e4922f',
#   'defaultAnnotation': {'Human face': {'category': 'Human face',
#     'informationType': '1',
#     'informationTypeInput': '',
#     'sharing': '2',
#     'sharingInput': '',
#     'ifNoPrivacy': False,
#     'informativeness': 6},
#    'Person': {'category': 'Person',
#     'informationType': '1',
#     'informationTypeInput': '',
#     'sharing': '2',
#     'sharingInput': '',
#     'ifNoPrivacy': False,
#     'informativeness': 6},
#    'Clothing': {'category': 'Clothing',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'Land vehicle': {'category': 'Land vehicle',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'Van': {'category': 'Van',
#     'informationType': '1',
#     'informationTypeInput': '',
#     'sharing': '2',
#     'sharingInput': '',
#     'ifNoPrivacy': False,
#     'informativeness': 6},
#    'Human head': {'category': 'Human head',
#     'informationType': '1',
#     'informationTypeInput': '',
#     'sharing': '2',
#     'sharingInput': '',
#     'ifNoPrivacy': False,
#     'informativeness': 6},
#    'Vehicle': {'category': 'Vehicle',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4}},
#   'manualAnnotation': {},
#   'file': '015f5cd905204962.jpg'},
#  {'source': 'OpenImages',
#   'workerId': '5da760eae8174b001640d369',
#   'defaultAnnotation': {'Human face': {'category': 'Human face',
#     'informationType': '1',
#     'informationTypeInput': '',
#     'sharing': '2',
#     'sharingInput': '',
#     'ifNoPrivacy': False,
#     'informativeness': 6},
#    'Human hair': {'category': 'Human hair',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'Human nose': {'category': 'Human nose',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'Human body': {'category': 'Human body',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'Human head': {'category': 'Human head',
#     'informationType': '1',
#     'informationTypeInput': '',
#     'sharing': '2',
#     'sharingInput': '',
#     'ifNoPrivacy': False,
#     'informativeness': 5},
#    'Human eye': {'category': 'Human eye',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'Human ear': {'category': 'Human ear',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'Human mouth': {'category': 'Human mouth',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'Boy': {'category': 'Boy',
#     'informationType': '1',
#     'informationTypeInput': '',
#     'sharing': '2',
#     'sharingInput': '',
#     'ifNoPrivacy': False,
#     'informativeness': 6},
#    'Human arm': {'category': 'Human arm',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'Man': {'category': 'Man',
#     'informationType': '1',
#     'informationTypeInput': '',
#     'sharing': '2',
#     'sharingInput': '',
#     'ifNoPrivacy': False,
#     'informativeness': 6}},
#   'manualAnnotation': {},
#   'file': '02eb8d9a3e34b370.jpg'},
#  {'source': 'OpenImages',
#   'workerId': '5f5a14224848f606446bbca8',
#   'defaultAnnotation': {'Human face': {'category': 'Human face',
#     'informationType': '1',
#     'informationTypeInput': '',
#     'sharing': '1',
#     'sharingInput': '',
#     'ifNoPrivacy': False,
#     'informativeness': 4},
#    'Human hair': {'category': 'Human hair',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'Glasses': {'category': 'Glasses',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'Sunglasses': {'category': 'Sunglasses',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'Human nose': {'category': 'Human nose',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'Clothing': {'category': 'Clothing',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'Human body': {'category': 'Human body',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'Human head': {'category': 'Human head',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'Helmet': {'category': 'Helmet',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'Goggles': {'category': 'Goggles',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'Human beard': {'category': 'Human beard',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'Man': {'category': 'Man',
#     'informationType': '1',
#     'informationTypeInput': '',
#     'sharing': '1',
#     'sharingInput': '',
#     'ifNoPrivacy': False,
#     'informativeness': 4}},
#   'manualAnnotation': {},
#   'file': '05c6fc62d2980f50.jpg'},
#  {'source': 'OpenImages',
#   'workerId': '612d5c73f67d20f6fe2f7400',
#   'defaultAnnotation': {'Human face': {'category': 'Human face',
#     'informationType': '1',
#     'informationTypeInput': '',
#     'sharing': '1',
#     'sharingInput': '',
#     'ifNoPrivacy': False,
#     'informativeness': 6},
#    'Human hair': {'category': 'Human hair',
#     'informationType': '1',
#     'informationTypeInput': '',
#     'sharing': '2',
#     'sharingInput': '',
#     'ifNoPrivacy': False,
#     'informativeness': 5},
#    'Fashion accessory': {'category': 'Fashion accessory',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'Girl': {'category': 'Girl',
#     'informationType': '1',
#     'informationTypeInput': '',
#     'sharing': '1',
#     'sharingInput': '',
#     'ifNoPrivacy': False,
#     'informativeness': 7},
#    'Person': {'category': 'Person',
#     'informationType': '1',
#     'informationTypeInput': '',
#     'sharing': '1',
#     'sharingInput': '',
#     'ifNoPrivacy': False,
#     'informativeness': 7},
#    'Clothing': {'category': 'Clothing',
# ...
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'Table tennis racket': {'category': 'Table tennis racket',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'Human hand': {'category': 'Human hand',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'Table': {'category': 'Table',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'Human mouth': {'category': 'Human mouth',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'Sports equipment': {'category': 'Sports equipment',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'Human arm': {'category': 'Human arm',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'Woman': {'category': 'Woman',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'Man': {'category': 'Man',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4}},
#   'manualAnnotation': {},
#   'file': '0f0297c3c92c39c1.jpg'},
#  {'source': 'OpenImages',
#   'workerId': 'mirin036',
#   'defaultAnnotation': {'Human face': {'category': 'Human face',
#     'informationType': '1',
#     'informationTypeInput': '',
#     'sharing': '2',
#     'sharingInput': '',
#     'ifNoPrivacy': False,
#     'informativeness': 6},
#    'Person': {'category': 'Person',
#     'informationType': '1',
#     'informationTypeInput': '',
#     'sharing': '2',
#     'sharingInput': '',
#     'ifNoPrivacy': False,
#     'informativeness': 6},
#    'Human nose': {'category': 'Human nose',
#     'informationType': '1',
#     'informationTypeInput': '',
#     'sharing': '2',
#     'sharingInput': '',
#     'ifNoPrivacy': False,
#     'informativeness': 5},
#    'Clothing': {'category': 'Clothing',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'Human head': {'category': 'Human head',
#     'informationType': '1',
#     'informationTypeInput': '',
#     'sharing': '2',
#     'sharingInput': '',
#     'ifNoPrivacy': False,
#     'informativeness': 6},
#    'Human eye': {'category': 'Human eye',
#     'informationType': '1',
#     'informationTypeInput': '',
#     'sharing': '2',
#     'sharingInput': '',
#     'ifNoPrivacy': False,
#     'informativeness': 5},
#    'Human mouth': {'category': 'Human mouth',
#     'informationType': '1',
#     'informationTypeInput': '',
#     'sharing': '2',
#     'sharingInput': '',
#     'ifNoPrivacy': False,
#     'informativeness': 5},
#    'Picture frame': {'category': 'Picture frame',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4}},
#   'manualAnnotation': {},
#   'file': '657079b4a2bd7cb4.jpg'},
#  {'source': 'OpenImages',
#   'workerId': '373913',
#   'defaultAnnotation': {'Human face': {'category': 'Human face',
#     'informationType': '1',
#     'informationTypeInput': '',
#     'sharing': '2',
#     'sharingInput': '',
#     'ifNoPrivacy': False,
#     'informativeness': 7},
#    'Human hair': {'category': 'Human hair',
#     'informationType': '1',
#     'informationTypeInput': '',
#     'sharing': '2',
#     'sharingInput': '',
#     'ifNoPrivacy': False,
#     'informativeness': 6},
#    'Human leg': {'category': 'Human leg',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'Car': {'category': 'Car',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'Person': {'category': 'Person',
#     'informationType': '1',
#     'informationTypeInput': '',
#     'sharing': '2',
#     'sharingInput': '',
#     'ifNoPrivacy': False,
#     'informativeness': 7},
#    'Human nose': {'category': 'Human nose',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'Clothing': {'category': 'Clothing',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'Human body': {'category': 'Human body',
#     'informationType': '1',
#     'informationTypeInput': '',
#     'sharing': '2',
#     'sharingInput': '',
#     'ifNoPrivacy': False,
#     'informativeness': 7},
#    'Human head': {'category': 'Human head',
#     'informationType': '1',
#     'informationTypeInput': '',
#     'sharing': '2',
#     'sharingInput': '',
#     'ifNoPrivacy': False,
#     'informativeness': 6},
#    'Human eye': {'category': 'Human eye',
#     'informationType': '1',
#     'informationTypeInput': '',
#     'sharing': '2',
#     'sharingInput': '',
#     'ifNoPrivacy': False,
#     'informativeness': 6},
#    'Human hand': {'category': 'Human hand',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'Footwear': {'category': 'Footwear',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'Wheel': {'category': 'Wheel',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'Boy': {'category': 'Boy',
#     'informationType': '1',
#     'informationTypeInput': '',
#     'sharing': '2',
#     'sharingInput': '',
#     'ifNoPrivacy': False,
#     'informativeness': 7},
#    'Toy': {'category': 'Toy',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'Human arm': {'category': 'Human arm',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4}},
#   'manualAnnotation': {},
#   'file': '1ffc718338acc984.jpg'},
#  {'source': 'OpenImages',
#   'workerId': '1764827',
#   'defaultAnnotation': {'Human face': {'category': 'Human face',
#     'informationType': '1',
#     'informationTypeInput': '',
#     'sharing': '2',
#     'sharingInput': '',
#     'ifNoPrivacy': False,
#     'informativeness': 7},
#    'Furniture': {'category': 'Furniture',
#     'informationType': '2',
#     'informationTypeInput': '',
#     'sharing': '2',
#     'sharingInput': '',
#     'ifNoPrivacy': False,
#     'informativeness': 5},
#    'Building': {'category': 'Building',
#     'informationType': '2',
#     'informationTypeInput': '',
#     'sharing': '2',
#     'sharingInput': '',
#     'ifNoPrivacy': False,
#     'informativeness': 7},
#    'Girl': {'category': 'Girl',
#     'informationType': '1',
#     'informationTypeInput': '',
#     'sharing': '2',
#     'sharingInput': '',
#     'ifNoPrivacy': False,
#     'informativeness': 7},
#    'Person': {'category': 'Person',
#     'informationType': '1',
#     'informationTypeInput': '',
#     'sharing': '2',
#     'sharingInput': '',
#     'ifNoPrivacy': False,
#     'informativeness': 7},
#    'Clothing': {'category': 'Clothing',
#     'informationType': '3',
#     'informationTypeInput': '',
#     'sharing': '2',
#     'sharingInput': '',
#     'ifNoPrivacy': False,
#     'informativeness': 5},
#    'Human head': {'category': 'Human head',
#     'informationType': '1',
#     'informationTypeInput': '',
#     'sharing': '2',
#     'sharingInput': '',
#     'ifNoPrivacy': False,
#     'informativeness': 7},
#    'Table': {'category': 'Table',
#     'informationType': '2',
#     'informationTypeInput': '',
#     'sharing': '2',
#     'sharingInput': '',
#     'ifNoPrivacy': False,
#     'informativeness': 5},
#    'Human mouth': {'category': 'Human mouth',
#     'informationType': '1',
#     'informationTypeInput': '',
#     'sharing': '2',
#     'sharingInput': '',
#     'ifNoPrivacy': False,
#     'informativeness': 6},
#    'Human arm': {'category': 'Human arm',
#     'informationType': '1',
#     'informationTypeInput': '',
#     'sharing': '2',
#     'sharingInput': '',
#     'ifNoPrivacy': False,
#     'informativeness': 5}},
#   'manualAnnotation': {},
#   'file': '01f26ca52e27a8d9.jpg'},
#  {'source': 'LVIS',
#   'workerId': '1523010',
#   'defaultAnnotation': {'fireplug': {'category': 'fireplug',
#     'informationType': '2',
#     'informationTypeInput': '',
#     'sharing': '2',
#     'sharingInput': '',
#     'ifNoPrivacy': False,
#     'informativeness': 3},
#    'sunglasses': {'category': 'sunglasses',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'necklace': {'category': 'necklace',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'license_plate': {'category': 'license_plate',
#     'informationType': '1',
#     'informationTypeInput': '',
#     'sharing': '1',
#     'sharingInput': '',
#     'ifNoPrivacy': False,
#     'informativeness': 3}},
#   'manualAnnotation': {'0': {'category': 'face',
#     'bbox': [127, 131, 62, 80],
#     'informationType': '1',
#     'informationTypeInput': '',
#     'sharing': '2',
#     'sharingInput': '',
#     'informativeness': 7}},
#   'file': '124786.jpg'},
#  {'source': 'OpenImages',
#   'workerId': '733149',
#   'defaultAnnotation': {'Human face': {'category': 'Human face',
#     'informationType': '1',
#     'informationTypeInput': '',
#     'sharing': '1',
#     'sharingInput': '',
#     'ifNoPrivacy': False,
#     'informativeness': 4},
#    'Human hair': {'category': 'Human hair',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'Human nose': {'category': 'Human nose',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'Clothing': {'category': 'Clothing',
#     'informationType': '4',
#     'informationTypeInput': '',
#     'sharing': '1',
#     'sharingInput': '',
#     'ifNoPrivacy': False,
#     'informativeness': 5},
#    'Human body': {'category': 'Human body',
#     'informationType': '1',
#     'informationTypeInput': '',
#     'sharing': '1',
#     'sharingInput': '',
#     'ifNoPrivacy': False,
#     'informativeness': 6},
#    'Human head': {'category': 'Human head',
#     'informationType': '1',
#     'informationTypeInput': '',
#     'sharing': '1',
#     'sharingInput': '',
#     'ifNoPrivacy': False,
#     'informativeness': 4},
#    'Mammal': {'category': 'Mammal',
#     'informationType': '1',
#     'informationTypeInput': '',
#     'sharing': '1',
#     'sharingInput': '',
#     'ifNoPrivacy': False,
#     'informativeness': 6},
#    'Man': {'category': 'Man',
#     'informationType': '1',
#     'informationTypeInput': '',
#     'sharing': '1',
#     'sharingInput': '',
#     'ifNoPrivacy': False,
#     'informativeness': 6}},
#   'manualAnnotation': {},
#   'file': '0222c555d2c21a2f.jpg'},
#  {'source': 'OpenImages',
#   'workerId': '712304',
#   'defaultAnnotation': {'Human face': {'category': 'Human face',
#     'informationType': '1',
#     'informationTypeInput': '',
#     'sharing': '1',
#     'sharingInput': '',
#     'ifNoPrivacy': False,
#     'informativeness': 7},
#    'Human hair': {'category': 'Human hair',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'Musical instrument': {'category': 'Musical instrument',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'Human nose': {'category': 'Human nose',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'Clothing': {'category': 'Clothing',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'Human body': {'category': 'Human body',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'Human head': {'category': 'Human head',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'Human eye': {'category': 'Human eye',
#     'informationType': '1',
#     'informationTypeInput': '',
#     'sharing': '1',
#     'sharingInput': '',
#     'ifNoPrivacy': False,
#     'informativeness': 6},
#    'Human hand': {'category': 'Human hand',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'Human mouth': {'category': 'Human mouth',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'Human arm': {'category': 'Human arm',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'Man': {'category': 'Man',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4}},
#   'manualAnnotation': {},
#   'file': '18da2f5082dcfbfc.jpg'},
#  {'source': 'OpenImages',
#   'workerId': '3443712',
#   'defaultAnnotation': {'Human face': {'category': 'Human face',
#     'informationType': '1',
#     'informationTypeInput': '',
#     'sharing': '2',
#     'sharingInput': '',
#     'ifNoPrivacy': False,
#     'informativeness': 4},
#    'Human hair': {'category': 'Human hair',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'Shirt': {'category': 'Shirt',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'Human nose': {'category': 'Human nose',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'Human body': {'category': 'Human body',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'Human head': {'category': 'Human head',
#     'informationType': '3',
#     'informationTypeInput': '',
#     'sharing': '2',
#     'sharingInput': '',
#     'ifNoPrivacy': False,
#     'informativeness': 4},
#    'Human eye': {'category': 'Human eye',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'Human beard': {'category': 'Human beard',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4},
#    'Man': {'category': 'Man',
#     'informationType': '',
#     'informationTypeInput': '',
#     'sharing': '',
#     'sharingInput': '',
#     'ifNoPrivacy': True,
#     'informativeness': 4}},
#   'manualAnnotation': {},
#   'file': '02879d3014b69b1f.jpg'}]

# %%
list(bob["manualAnnotation"].values())
# Out:
# [{'category': 'Individuals face',
#   'bbox': [56, 80, 53, 59],
#   'informationType': '1',
#   'informationTypeInput': '',
#   'sharing': '1',
#   'sharingInput': '',
#   'informativeness': 4}]
